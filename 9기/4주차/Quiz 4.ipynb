# %% [markdown]
# # Q1

# %% [markdown]
# * z = (k + 3)^3
# * k = (x + y)^2
#
# * z = ((x + y)^2 + 3)^3
#
# * z를 x에 대해 미분
#     * 3((x+y)^2 + 3)^2 * 2(x + y) = **6((x + y )^2 + 3)^2(x + y)**

# %% [markdown]
# # Q2

# %% [markdown]
# * 신경망에서 활성함수가 필요한 이유
#     * 활성함수는 비선형 함수이다.
#     * 활성 함수를 쓰지 않으면 선형 모형과 차이가 없다.
#     * **결론 : 비선형 근사를 하기 위해서**

# %% [markdown]
# # Q3

# %% [markdown]
# * 역전파 알고리즘은 연쇄법칙 기반 자동미분을 사용한다.

# %% [markdown]
# # Q4

# %% [markdown]
# * 이산형 확률변수는 확률변수가 가질 수 있는 경우의 수를 모두 고려하여 확률을 더해서 모델링 한다.
#
# ![image.png](data:image/png;base64,...)
#
# * 연속형 확률변수는 데이터 공간에 정의된확률변수의 밀도 위에서의 적분을 통해 모델링한다.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Q5

# %% [markdown]
# * 연속형 확률변수의 한 지점에서의 밀도는 그 자체로 확률값을 가진다.
#     * 밀도는 확률이 아닌 변화율을 의미하므로 한 지점에서의 밀도는 0이다.

# %% [markdown]
# # Q6

# %% [markdown]
# E(X) = 1/6 * (1+2+3+4+5+6) = 3.5

# %% [markdown]
# # Q7

# %% [markdown]
# 정답 레이블을 ONE-HOT벡터로 표현한다면 하나의 정답 레이블 벡터의 크기는 1이 아니라 레이블 수? 이지 않을까??
# * 2 이상일 것 같다.

# %% [markdown]
# # Q8

# %% [markdown]
# 1,2,3,4,5의 평균은 3
