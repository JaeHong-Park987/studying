# %% [markdown]
# # 파트 소개 및 실습 환경 설정

# %% [markdown]
# ## 도커 환경설정

# %% [markdown]
# * 도커 : 컨테이너 기반의 가상 시스템
#     * LINUX 기반

# %% [markdown]
# # Machine Learning & PyTorch Basic

# %% [markdown]
# ## Tensor Manipulation 1
