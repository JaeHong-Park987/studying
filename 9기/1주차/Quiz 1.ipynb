# %% [markdown]
# # Q1

# %% [markdown]
# * 파이썬 특징
#     1. 플랫폼 독립적
#     2. 인터프리터 언어
#     3. 객체 지향
#     4. 동적 타이핑 언어
#     5. 처음 C로 구현되었음

# %% [markdown]
# # Q2

# %% [markdown]
# * 파이썬 기본 자료형
#     1. integer
#     2. float
#     3. string
#     4. boolean

# %% [markdown]
# # Q3

# %%
a = 10
float(a)
type(a)
# Out:
# int

# %% [markdown]
# # Q4

# %%
name = 'Apple'
price = 5600
number = 7

print("{2}, {1}, {0}".format(number, name, price))
# Out:
# 5600, Apple, 7

# %% [markdown]
# # Q5

# %%
test_list = ['치킨', '피자', '삼겹살', '족발', '초밥', '소주']
print(test_list[1::2])
# Out:
# ['피자', '족발', '소주']

# %%
print(test_list[1:5:2])
# Out:
# ['피자', '족발']

# %% [markdown]
# # Q6

# %%
for data in test_list[::2]:
    if len(data) == 3:
        print(data)
# Out:
# 삼겹살

# %% [markdown]
# # Q7

# %%
def print_greedings(t):
    t = "Hello."
    print("In Fn : ", t)

x = "HI."
print_greedings(x)
print("Out Fn :", x)
# Out:
# In Fn :  Hello.
# Out Fn : HI.

# %% [markdown]
# # Q8

# %%
string = "#You #Only #Live #Once."

# %%
string.split("#")
# Out:
# ['', 'You ', 'Only ', 'Live ', 'Once.']

# %%
string.replace("#","")
# Out:
# 'You Only Live Once.'

# %%
string.rstrip()
# Out:
# '#You #Only #Live #Once.'

# %% [markdown]
# # Q9

# %%
a , b, *c = (14, 21, 25, 39, 46, 57) # 가변변수
print(c)
# Out:
# [25, 39, 46, 57]

# %%
print(a)
# Out:
# 14

# %%
print(b)
# Out:
# 21

# %%
print(c)
# Out:
# [25, 39, 46, 57]

# %% [markdown]
# # Q10

# %%
data_list = [0, 1, 2, 3, 4, 5]

def f(x):
    return x ** 5

[f(value) for value in data_list]
# Out:
# [0, 1, 32, 243, 1024, 3125]
