# %% [markdown]
# # Q1

# %%
class Company():
    def __init__(self, name):
        self.company_name = name

# %%
company = Company():naver
# Out:
#   File "<ipython-input-2-86b0c7ff6d3a>", line 1
#     company = Company():naver
#                        ^
# SyntaxError: invalid syntax

# %%
company=Company()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-66b38c1703b5> in <module>
# ----> 1 company=Company()
#
# TypeError: __init__() missing 1 required positional argument: 'name'

# %%
company = Company
company
# Out:
# __main__.Company

# %%
company = Company("naver")
company

# %% [markdown]
# # Q2

# %%
class Car():
    def __init__(self):
        self.model = "BEN"
    
    def change_model(self):
        self.model = "CAR"

    def change_model_another(self):
        self.model = "TRUCK"

car = Car()
print(car.model)
car.change_model_another()
print(car.model)
car.change_model()
print(car.model)
# Out:
# BEN
# TRUCK
# CAR

# %% [markdown]
# ## Q3

# %%
class House():
    def __init__(self):
        self.__door = [] # private 변수로 변경

# %% [markdown]
# # Q4

# %% [markdown]
# * OOP의 개념에서 필요한 요소
#     * 상속 : Inheritance
#     * 다형성 : Polymorphism
#     * 가시성 : Visibility

# %% [markdown]
# # Q5

# %%
class Person():
    def __init__(self):
        self.name = "SJ"
        self.age = 20

class Player(Person):
    pass

the_player = Player()
print(the_player.name)
# Out:
# SJ

# %% [markdown]
# # Q6

# %%
import random as rd

# %%
random.random()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-1e16b7152bea> in <module>
# ----> 1 random.random()
#
# NameError: name 'random' is not defined

# %%
random()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-347a394b3b57> in <module>
# ----> 1 random()
#
# NameError: name 'random' is not defined

# %%
rd.random()
# Out:
# 0.14705326376070238

# %%
rd.rd()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-7ce79869102d> in <module>
# ----> 1 rd.rd()
#
# AttributeError: module 'random' has no attribute 'rd'

# %% [markdown]
# # Q7

# %%
for i in range(3):
    res_list = []
    try:
        result = 10/i
        print(result)
        res_list.append(result)
    except ZeroDivisionError:
        print("Not divided by 0")
# Out:
# Not divided by 0
# 10.0
# 5.0

# %% [markdown]
# # Q8

# %% [markdown]
# * f = open("filename", "mode")에서 mode에 들어갈 수 있는 것
#     * r : 읽기모드 - 파일을 읽기만 할 때 사용
#     * w : 쓰기모드 - 파일에 내용을 쓸 때 사용
#     * a : 추가모드 - 파일의 마지막에 새로운 내용을 추가 시킬 때 사용

# %% [markdown]
# # Q9

# %% [markdown]
# csv.reader(f, delimiter = ',', quotechar = '"', quoting = csv.QUOTE_ALL)
#
# * delimiter -> 글자를 나누는 기준
#     * default : ,
# * lineterminator : 줄 바꿈 기준
#     * default : \r\n
# * quotechar : 문자열을 둘러싸는 신호 문자
#     * default : "
# * quoting : 데이터 나누는 기준이 quotechar에 의해 둘러싸인 레벨
#     * default : QUOTE_MINIMAL

# %% [markdown]
# # Q10

# %% [markdown]
# * 정규식
#     * '?' : 반복 횟수가 1회
#     * '*' : 앞에 있는 글자를 반복해서 나올 수 있음
#     * '.' : 줄바꿈 문자인 \n를 제외한 모든 문자와 매치
#     * '^' : not
#     * '|' : or
